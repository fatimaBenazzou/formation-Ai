# %% [markdown]
# # Algeria Ai

# %% [markdown]
# ## Checkpoint 3

# %% [markdown]
# 1. Explore this dataset using what you have learned in data preprocessing and
# data visualization

# %% [markdown]
# #### load data

# %%
import numpy as np 
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
# readding data and create dataframe
data = pd.read_csv(r"C:/Users/auros/Documents/Formations/Ai/kc_house_data.csv",delimiter=',')
df=pd.DataFrame(data)

data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %% [markdown]
# #### Data Preprossessing

# %%
# Finding the missing values
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [markdown]
# there is no missing data

# %% [markdown]
# ##### Data transformation

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
columns_to_normalize = ['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'waterfront', 
                        'view', 'condition', 'grade', 'sqft_above', 'sqft_basement', 'yr_built', 
                        'yr_renovated', 'lat', 'long', 'sqft_living15', 'sqft_lot15']

scaler = MinMaxScaler()
df[columns_to_normalize] = scaler.fit_transform(df[columns_to_normalize])
print(df.head())
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  0.019266  0.090909    0.12500     0.067170
# 1  6414100192  20141209T000000  0.060721  0.090909    0.28125     0.172075
# 2  5631500400  20150225T000000  0.013770  0.060606    0.12500     0.036226
# 3  2487200875  20141209T000000  0.069377  0.121212    0.37500     0.126038
# 4  1954400510  20150218T000000  0.057049  0.090909    0.25000     0.104906
#
#    sqft_lot  floors  waterfront  view  ...     grade  sqft_above  \
# 0  0.003108     0.0         0.0   0.0  ...  0.500000    0.097588
# 1  0.004072     0.4         0.0   0.0  ...  0.500000    0.206140
# 2  0.005743     0.0         0.0   0.0  ...  0.416667    0.052632
# 3  0.002714     0.0         0.0   0.0  ...  0.500000    0.083333
# 4  0.004579     0.0         0.0   0.0  ...  0.583333    0.152412
#
#    sqft_basement  yr_built  yr_renovated  zipcode       lat      long  \
# ...

# %% [markdown]
# #### Data visualisation

# %%
# Visualisation de la distribution de la variable cible (Price)
plt.figure(figsize=(10, 6))
plt.hist(df['price'], bins=20, color='skyblue')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.title('Distribution des Prix des Maisons')
plt.show()

# %%
sns.countplot(df.bedrooms,order=df['bedrooms'].value_counts().index)
# Out:
# c:\Users\auros\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='bedrooms', ylabel='count'>

# %%
fig,axes=plt.subplots(nrows=1,ncols=1,figsize=(15,10))
plt.title("house prices by sqft_above")
plt.xlabel('sqft_above')
plt.ylabel('house prices')
plt.legend()
sns.barplot(x='sqft_above',y='price',data=df)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# <AxesSubplot:title={'center':'house prices by sqft_above'}, xlabel='sqft_above', ylabel='price'>

# %%
fig,axes=plt.subplots(nrows=1,ncols=1,figsize=(15,10))
plt.title("house prices by sqft_above")
plt.xlabel('sqft_above')
plt.ylabel('house prices')
plt.legend()
sns.barplot(x='sqft_above',y='price',data=df)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# <AxesSubplot:title={'center':'house prices by sqft_above'}, xlabel='sqft_above', ylabel='price'>

# %%
plt.hist('sqft_living',data=df,bins=5, color='skyblue')
# Out:
# (array([1.8284e+04, 3.2210e+03, 1.0100e+02, 5.0000e+00, 2.0000e+00]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]),
#  <BarContainer object of 5 artists>)

# %%
fig,axes=plt.subplots(nrows=1,ncols=1,figsize=(15,10))
sns.distplot(df['sqft_living'],hist=True,kde=True,rug=False,label='sqft_living',norm_hist=True, color='skyblue')
# Out:
# c:\Users\auros\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='sqft_living', ylabel='Density'>

# %%
# Fonction pour afficher la heatmap de corrélation
def correlation_heatmap(df1):
    _, ax = plt.subplots(figsize=(15, 10))
    colormap = sns.diverging_palette(220, 10, as_cmap=True)
    sns.heatmap(df1.corr(), annot=True, cmap=colormap)

correlation_heatmap(df)

# %% [markdown]
# 3. Split your dataset into a training set and a testing set.

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn import metrics

# %%
train_data,test_data=train_test_split(df,train_size=0.8,random_state=3)

# %%
X_train=np.array(train_data['sqft_living']).reshape(-1,1)
y_train=np.array(train_data['price']).reshape(-1,1)

X_test=np.array(test_data['sqft_living']).reshape(-1,1)
y_test=np.array(test_data['price']).reshape(-1,1)

# %% [markdown]
# 4. Apply Linear regression to your training set.

# %%
# Initialisation du modèle
model = LinearRegression()

# Entraînement du modèle sur l'ensemble d'entraînement
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# 5. Plot the linear regression.

# %%
_, ax = plt.subplots(figsize= (12, 10))
plt.scatter(X_test, y_test, color= 'pink', label = 'data')
plt.plot(X_test, model.predict(X_test), color='red', label= ' Predicted Regression line')
plt.xlabel('Living Space (sqft)')
plt.ylabel('price')
plt.legend()
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# %% [markdown]
# 6. Measure the performance of linear regression using the testing set.

# %%
# Prédictions sur l'ensemble de test
y_pred = model.predict(X_test)
print('linear model')

# Calcul des métriques de performance
mae = metrics.mean_absolute_error(y_test, y_pred)
mse = metrics.mean_squared_error(y_test, y_pred)
r_squared = model.score(X_test, y_test)
rmse = np.sqrt(mse)

print(f'Mean Absolute Error: {round(mae, 2)}') 
print(f'Mean Squared Error: {round(mse, 2)}') 
print(f'R Mean Squared Error: {round(rmse, 2)}') 
print(f'R-squared: {round(r_squared, 3)}')
# Out:
# linear model
# Mean Absolute Error: 0.02
# Mean Squared Error: 0.0
# R Mean Squared Error: 0.03
# R-squared: 0.496

# %% [markdown]
# 7. Apply multi-linear regression and compare it to the linear model.

# %%
fig,ax=plt.subplots(2,1,figsize=(15,10))
sns.boxplot(x=train_data['grade'],y=train_data['price'],ax=ax[0])
sns.boxplot(x=train_data['bedrooms'],y=train_data['price'],ax=ax[1])
_ , axes = plt.subplots(1, 1, figsize=(15,10))
sns.boxplot(x=train_data['bathrooms'],y=train_data['price'])
# Out:
# <AxesSubplot:xlabel='bathrooms', ylabel='price'>

# %%
features1=['bedrooms','grade','sqft_living','sqft_above']

modelMult=LinearRegression()
modelMult.fit(train_data[features1],train_data['price'])
pred=modelMult.predict(test_data[features1])
print('complex_model 1')

mse_multi=metrics.mean_squared_error(y_test,pred)
print('R mean squared error(RMSE)', round((mse_multi),2))
print('R squared',round(modelMult.score(train_data[features1],train_data['price']),3))
# Out:
# complex_model 1
# R mean squared error(RMSE) 0.0
# R squared 0.548

# %%
# Comparaison des erreurs
if mse_multi < mse:
    print("La régression multi a une erreur quadratique moyenne inférieure, elle semble être plus performante.")
else:
    print("La régression linéaire a une erreur quadratique moyenne inférieure, elle semble être plus performante.")
# Out:
# La régression multi a une erreur quadratique moyenne inférieure, elle semble être plus performante.

# %% [markdown]
# 8. Apply Polynomial regression and compare it to linear and ultilinear regression.

# %%
# Assuming X_train and X_test are your feature matrices, and y_train, y_test are your target variables

polyfeat=PolynomialFeatures(degree=2)
xtrain_poly=polyfeat.fit_transform(train_data[features1])
xtest_poly=polyfeat.fit_transform(test_data[features1])

poly=LinearRegression()
poly.fit(xtrain_poly,train_data['price'])
polypred=poly.predict(xtest_poly)

print('Complex Model_3')
mse_poly = metrics.mean_squared_error(test_data['price'], polypred)
print('R Mean Squared Error (RMSE) ', round((mse_poly), 2))
print('R-squared ', round(poly.score(xtrain_poly, train_data['price']), 3))
# Out:
# Complex Model_3
# R Mean Squared Error (RMSE)  0.0
# R-squared  0.614

# %%
# Comparaison des modèles
if mse_multi < mse and mse_multi < mse_poly:
    print("La régression multi a une erreur quadratique moyenne inférieure, elle semble être plus performante.")
elif mse_poly < mse:
    print("La régression polynomiale a une erreur quadratique moyenne inférieure, elle semble être plus performante.")
else:
    print("La régression linéaire a une erreur quadratique moyenne inférieure, elle semble être plus performante.")
# Out:
# La régression polynomiale a une erreur quadratique moyenne inférieure, elle semble être plus performante.
